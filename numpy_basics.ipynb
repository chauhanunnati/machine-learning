# %%
import numpy as np

# %%
a = np.zeros(3) # type(a[0]) is float64
a
# Out:
# array([0., 0., 0.])

# %%
b = np.ones(5)
b.shape
# Out:
# (5,)

# %%
b.shape = (5, 1)
b
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
z = np.empty(3) # array of uninitialized data
z
# Out:
# array([0., 0., 0.])

# %%
z = np.linspace(0, 1, 5) # creates 5 points between 0 and 1
z
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
y = np.array([3, 2]) # 1D list to 1D array
y
# Out:
# array([3, 2])

# %%
a_list = [[1, 2], [3, 4]]
z = np.array(a_list) # creates a 2D array using python list
z
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
y = np.arange(0, 10, 2) # array with values from 0 to 10 with a step of 2
y
# Out:
# array([0, 2, 4, 6, 8])

# %% [markdown]
# linspace vs arange:
#
# linspace(Start, Stop, Number of values) -> Generates num evenly spaced numbers between start and stop (stop included).
#
# arange(Start, Stop, Step size) -> Generates values in a range using a specified step size.

# %%
x = np.random.randint(1, 7)
x # random integer between 1 and 6
# Out:
# 1

# %% [markdown]
# numpy.random.randint(low, high=None, size=None, dtype=int)

# %%
X = np.random.randint(1, 7, 4) # 4 random integers between 1 and 6
X
# Out:
# array([5, 2, 3, 4], dtype=int32)

# %% [markdown]
# Without setting the seed, every time we run our code, we'll get different random values.

# %%
np.random.seed(0) # set seed to get same values every time the code is executed
x = np.random.randint(1, 10, 5)
x
# Out:
# array([6, 1, 4, 4, 8], dtype=int32)

# %%
arr = np.array([10, 20, 30, 40, 50])
print(arr[0])   # using indices
arr[-1]  # last element
# Out:
# 10
# np.int64(50)

# %% [markdown]
# Slicing

# %%
print(arr[1:4])    # element first to fourth (exclusive)
print(arr[::2])    # every second element [start:end:step]
print(arr[::-1])   # reverse the array
# Out:
# [20 30 40]
# [10 30 50]
# [50 40 30 20 10]

# %%
indices = [0, 2, 4]
arr[indices]
# Out:
# array([10, 30, 50])

# %%
arr2d = np.array([[1, 2, 3], [4, 5, 6]])
arr2d[0, 1]  # Output: 2 (row 0, column 1)
# Out:
# np.int64(2)

# %%
print(arr2d[:, 1]) # all rows, column 1
print(arr2d[1, :]) # row 1, all columns
# Out:
# [2 5]
# [4 5 6]

# %% [markdown]
# Using np.where()

# %%
idx = np.where(arr > 30)
print(arr[idx])  # Output: [40 50]

# %%
# %pip install scikit-image
# Out:
# ^C
# ...
#   Using cached scikit_image-0.25.2-cp312-cp312-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Using cached scikit_image-0.25.2-cp312-cp312-win_amd64.whl (12.9 MB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# ...

# %%
from skimage import io
photo = io.imread('./assets/michael-scott-the-office.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape # (height, width, color channels)
# Out:
# (478, 850, 3)

# %%
io.imshow(photo) # show image
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13224\715873215.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(photo) # show image

# %% [markdown]
# Upside down Image

# %%
import matplotlib.pyplot as plt
# plt.imshow(photo) -> does the same thing as io.imshow(photo)
plt.imshow(photo[::-1])

# %% [markdown]
# Mirror Image

# %%
plt.imshow(photo[:, ::-1]) # flip image horizontally

# %% [markdown]
# Section / Slice the picture using array slicing

# %%
plt.imshow(photo[400:450, 250:550]) # crop image

# %%
plt.imshow(photo[::2, ::2]) 
# downsample image, take every other row and column -> dimensions are reduced to half

# %%
photo_sin = np.sin(photo) # apply sin function to each pixel value
# photo_sin is a numpy array with sin values
photo_sin[1, 2]
# Out:
# array([ 0.3132,  0.774 , -0.9937], dtype=float16)

# %% [markdown]
# Aggregate functions

# %%
arr = np.array([[1, 2], [3, 4]])
print(arr)
print(np.sum(arr)) # sum of all elements  
print(np.sum(arr, axis=0)) # sum of each column
print(np.sum(arr, axis=1)) # sum of each row
# Out:
# [[1 2]
#  [3 4]]
# 10
# [4 6]
# [3 7]

# %%
print(np.mean(arr)) # mean of all elements
print(np.median(arr)) # median
print(np.std(arr)) # standard deviation
print(np.var(arr)) # variance
# Out:
# 2.5
# 2.5
# 1.118033988749895
# 1.25

# %%
print(np.min(arr)) # minimum value
print(np.argmin(arr)) # index of minimum value

print(np.max(arr)) # maximum value
print(np.argmax(arr)) # index of maximum value
# Out:
# 1
# 0
# 4
# 3

# %%
print(np.cumsum(arr)) # cumulative sum
np.cumprod(arr) # cumulative product
# Out:
# [ 1  3  6 10]
# array([ 1,  2,  6, 24])

# %%
z = np.array([1, 2, 3, 4, 5])
z < 3
# Out:
# array([ True,  True, False, False, False])

# %%
z[z > 3]
# Out:
# array([4, 5])

# %% [markdown]
# Setting a threashold for a picture

# %%
photo_masked = np.where(photo > 200, 255, 0) # set all values greater than 200 to 255, others to 0
plt.imshow(photo_masked)

# %%
from skimage import color
photo_gray = color.rgb2gray(photo)
plt.imshow(photo_gray)

# %% [markdown]
# Operations of different numpy arrays

# %%
a_array = np.array([1, 2, 3, 4, 5])
b_array = np.array([6, 7, 8, 9, 10])

# %%
a_array + b_array # element-wise addition
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
a_array - 100 # subtraction with a scalar
# Out:
# array([-99, -98, -97, -96, -95])

# %%
a_array * -1 # multiplication with a scalar
# Out:
# array([-1, -2, -3, -4, -5])

# %%
a_array * b_array # element-wise multiplication
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
a_array @ b_array # matrix multiplication (dot product)
# Out:
# np.int64(130)

# %%
a = [55, 33, 11, 22, 66]
np.sort(a) # sort array
# Out:
# array([11, 22, 33, 55, 66])

# %% [markdown]
# Transpose of the image / array

# %%
plt.imshow(photo[:, :, 0].T)
# transpose the first color channel -> (height, width, color channels)
# R -> 0, G -> 1, B -> 2
